# %%
x=45
y=67

# %%
sum1=x+y 
print(sum1)
# Out:
# 112

# %%
sum1
# Out:
# 112

# %%
name= ''' rohan's 
village '''

# %%
type(name)
# Out:
# str

# %%
z=4+\
5  
print(z)
# Out:
# 9

# %%
c=4+6j

# %%
type(c)
# Out:
# complex

# %%
d34={"a":1,"b":2}

# %%
type(d34)
# Out:
# dict

# %%
True+False
# Out:
# 1

# %%
print(True+False)
# Out:
# 1

# %%
d34["a"]=100

# %%
d34
# Out:
# {'a': 100, 'b': 2}

# %%
s="amity"

# %%
s[0:5:2]
# Out:
# 'aiy'

# %%
s[::-1]
# Out:
# 'ytima'

# %%
s[-4:-1]
# Out:
# 'mit'

# %%
s[]
# Out:
#   Cell In[19], line 1
#     s[]
#       ^
# SyntaxError: invalid syntax

# %%
s[-1:-4:-1]

# %%
s[-1:-4:-1]

# %%
s[::-1]

# %%
l34=[2,3,4,"ab",5]

# %%
type(l34)

# %%
l34[1:3]

# %%
l34[0]=8

# %%
l34

# %%
s34={3,4,5,[2,34,6]}

# %%
type(s34)

# %%
name="Satyam"

# %%
name.replace("S","t")

# %%
print(name)

# %%
s35={"a","a",1,3,4,4}

# %%
s35

# %%
t23=("a",1,"b")

# %%
type(t23)

# %%
t34=(4,)

# %%
type(t34)

# %%
5+5

# %%
"s"+"2"

# %%
5//2

# %%
5%2

# %%
25**(1/2)

# %%
num1=45 
num2=num1

# %%
num1 is num2

# %%
id(num1) ,id(num2)

# %%
"A" in "rAhu"

# %%
a=int(input("Enter Number1"))
b=int(input("Enter Number2") )
# type(print(a+b))
c=a+b

# %%
type(c)

# %%
print("hi","how",sep="&")

# %%
name="rahule" 
add="Jaipur" 
phn=9166 
print(name,end="\t") 
print(add) 
print(phn)

# %%
a=int(input("Enter First Number"))
b=int(input("Enter second Number"))
if True:
    print(a+b)
else:
    print(a-b)

# %%
a=int(input("Enter First Number"))
if a>10:
    print("first wala") 
    if a==18:
        print("jackpot")
    
if a>15: 
    print("Second wala")
else: 
    print("upar ka koi nahi")

# %%
email_t="s@gmail.com" 
password_t="123"
email=input("Enter  Mail")
password=input("Enter Passwor")
if (email_t==email) and (password_t==password):
    print("welcome") 
else:
    password=input("Enter Passwor again")
    if password==password_t:
        print("der aaye durust aaye")
    else:
        print("Tumse Na ho paayega")
# Out:
# Enter  Mail s@gmail.com
# Enter Passwor 12345
# Enter Passwor 123456
# Tumse Na ho paayega

# %%
number=int(input("Enter Number"))
new_num=0
a=number%10
number=number//10
new_num=new_num*10+a
b=number%10
number=number//10
new_num=new_num*10+b
c=number%10
number=number//10
new_num=new_num*10+c
print(new_num)
# Out:
# Enter Number 234
# 432

# %%
for ele in [2,3]:
    print("Hello Loops")
# Out:
# Hello Loops
# Hello Loops

# %%
range(1,10)
# Out:
# range(1, 10)

# %%
for ele in range(1,4):
    print(ele)
# Out:
# 1
# 2
# 3

# %%
print(range(1,4))
# Out:
# range(1, 4)

# %%
x=range(1,4)

# %%
(*x,)
# Out:
# (1, 2, 3)

# %%
for ele in "python":
    print(ele,end=" ")
# Out:
# p y t h o n

# %%
for ele in "123":
    print(ele)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 for ele in 123:
#       2     print(ele)
#
# TypeError: 'int' object is not iterable

# %%
a=3 
while a>0: 
    print("hello")
    a=a-.001
# Out:
# hello
# hello
# hello
